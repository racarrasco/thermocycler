# %% [markdown]
# #### PCR Thermal Cycling Controller
# Import libraries

# %%
import time
import serial
import numpy as np
import matplotlib.pyplot as plt
import sys
import glob
from IPython import display
from ipywidgets import widgets
from collections import deque
import PCR_cont as cnt
# %matplotlib inline
time.sleep(2)

# %% [markdown]
# Initialize serial communication

# %%
ser = cnt.serial_connect(baud=19200)
# Out:
# Checking serial connections...
# Available serial ports:
# [Detected] index:2 id:/dev/cu.usbmodem14131

# %% [markdown]
# Control Dashboard

# %%
dash=cnt.plotDash(ser)

# %% [markdown]
# Encode command

# %%
cmd=cnt.encodeCmd(dash)

# %% [markdown]
# Run!

# %%
cnt.runCmd(ser,cmd)
[dtemp, dtime]=cnt.runPlot(ser)
# Out:
# done

# %% [raw]
# print(dtemp)

# %%
import csv
with open('test.csv', 'w', newline='') as fp:
    a = csv.writer(fp, delimiter=',')
    data = np.transpose([dtemp, dtime])
    a.writerows(data)

# %% [markdown]
# Hardware test

# %%
cnt.turnonFan(ser)
time.sleep(2)
cnt.turnoffFan(ser)
cnt.turnonLed(ser,255)
time.sleep(1)                                                               
cnt.turnoffLed(ser)
print(cnt.getTemp(ser))
